# %%
# Read in txt file
with open("../data/input_4.txt") as file:
    batch = file.read().strip().split('\n\n')

# %%
required_fields = {'byr',
    'iyr',
    'eyr',
    'hgt',
    'hcl',
    'ecl',
    'pid'}

# %%
passports = list(map(lambda x: x.replace('\n', ' '), batch))

# %%
def create_dict_from_row(passport_string):
    return dict((x.strip(), y.strip())
        for x, y in (element.split(':') 
        for element in passport_string.split(' ')))

# %%
passport_dicts = list(map(create_dict_from_row, passports))

# %%
passport_valid_total = 0
for i in passport_dicts:
    if required_fields.intersection(i.keys()) == required_fields:
        passport_valid_total += 1
passport_valid_total
# Out:
# 245

# %%
# Add validation rules
# byr (Birth Year) - four digits; at least 1920 and at most 2002.
# iyr (Issue Year) - four digits; at least 2010 and at most 2020.
# eyr (Expiration Year) - four digits; at least 2020 and at most 2030.
# hgt (Height) - a number followed by either cm or in:
# If cm, the number must be at least 150 and at most 193.
# If in, the number must be at least 59 and at most 76.
# hcl (Hair Color) - a # followed by exactly six characters 0-9 or a-f.
# ecl (Eye Color) - exactly one of: amb blu brn gry grn hzl oth.
# pid (Passport ID) - a nine-digit number, including leading zeroes.
# cid (Country ID) - ignored, missing or not.
def validate(passport_dict):
    key = 
    is_valid = True
    if key == 'byr':
        entry = 
    else if key == 'iyr':
        pass
    else if key == 'eyr':
        pass
    else if key == 'hgt':
        pass
    else if key == 'hcl':
        pass
    else if key == 'ecl':
        pass
    else if key == 'pid':
        pass
    else if key == 'cid':
        pass
# Out:
#   File "<ipython-input-10-b854602c7fa4>", line 12
#     def validate()
#                   ^
# SyntaxError: invalid syntax

# %%
passport_dicts
# Out:
# [{'eyr': '2029',
#   'pid': '157374862',
#   'byr': '1991',
#   'ecl': 'amb',
#   'hcl': '#a97842',
#   'hgt': '178cm'},
#  {'byr': '1962',
#   'pid': '547578491',
#   'eyr': '2028',
#   'ecl': 'hzl',
#   'hgt': '65in',
#   'iyr': '2013',
#   'hcl': '#623a2f'},
#  {'hgt': '71in',
#   'eyr': '2037',
#   'ecl': '#8e276e',
#   'hcl': 'z',
#   'iyr': '2019',
#   'byr': '2022',
#   'pid': '157cm'},
#  {'hcl': '#733820',
#   'hgt': '175',
#   'eyr': '2028',
#   'iyr': '2011',
#   'pid': '87786389',
#   'ecl': 'hzl',
#   'byr': '1980'},
#  {'hgt': '163in',
#   'hcl': 'z',
#   'pid': '8261494508',
#   'cid': '136',
#   'ecl': 'grn',
#   'eyr': '1958',
#   'byr': '2030',
#   'iyr': '1991'},
#  {'iyr': '2021',
#   'hcl': '6708a3',
#   'ecl': 'zzz',
#   'eyr': '2034',
#   'byr': '2010',
#   'hgt': '189cm',
#   'pid': '466438311'},
#  {'iyr': '2012',
#   'pid': '9720867166',
#   'byr': '2006',
#   'eyr': '2022',
#   'hgt': '72cm',
#   'ecl': 'utc',
#   'hcl': '#c0946f'},
#  {'ecl': '#353bc9',
# ...
